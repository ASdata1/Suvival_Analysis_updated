# %%
from src.data_gen.scenario2_covariates import simulate_scenario2
from src.data_gen.scenario1_random import simulate_scenario1
from src.utils.eda import plot_correlation_matrix, plot_censoring_distribution, kap_meier_curve, true_weibell
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from lifelines import KaplanMeierFitter

# %%
df, params  = simulate_scenario2()

# %%
df.head()
# Out:
#          age        salary     tenure  ...      time  event             scenario
# 0  66.533177  22255.651054  18.882309  ...  3.927975      0  covariate_censoring
# 1  64.587079  32263.701662  20.169338  ...  6.164748      1  covariate_censoring
# 2  67.736858  45301.734373  25.858667  ...  0.974624      1  covariate_censoring
# 3  63.198318  29711.929480  19.502921  ...  1.467588      1  covariate_censoring
# 4  65.589131  34868.972478  17.012313  ...  4.052543      1  covariate_censoring
#
# [5 rows x 10 columns]

# %%
params
# Out:
# {'beta': [0.04, -0.03, 0.07],
#  'weibull_shape': 1.4,
#  'weibull_scale': 18.0,
#  'censoring_model_gamma': [0.02, -0.05, 0.01],
#  'censoring_type': 'covariate-dependent'}

# %%
plt.figure(figsize=(15, 6))

# First subplot

plot_correlation_matrix(df_random)

# Second subplot  

plot_correlation_matrix(df)


plt.tight_layout()  # Prevents overlapping
plt.show()
